# %%
pip install opencv-python-headless
pip install numpy
pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 27.9 MB/s eta 0:00:00:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading and displaying the image

# %%
# Read image. Read as bgr and converted back to rgb with displayed
the_img = cv2.imread("img.png")

# Set color map to gray scale for proper rendering.
plt.imshow(the_img)

# %%
# Read image as gray scale. Read as Grayscale
my_img = cv2.imread("img.png", 0)

# Set color map to gray scale for proper rendering.
plt.imshow(my_img, cmap="gray")

# %%
# cmap has many values to display images in various modes/renders
plt.imshow(my_img, cmap="turbo")

# %% [markdown]
# ### Cropping, Resizing and Flipping the image

# %%
# Cropping done by simple slicing the image numoy arrays
image = cv2.imread("img.png")
# plt.imshow(image)
# image.shape
crop_img = image[200:249,0:200]
plt.imshow(crop_img)

# %%
crop_img2 = image[88:195,0:200]
plt.imshow(crop_img2)

# %%
# Resize done by using resize function: resize( src, dsize[, dst[, fx[, fy[, interpolation]]]] )
# plt.imshow(image)
# Scale factors as 2 i.e. 2x
resized_2x = cv2.resize(image, None, fx=2, fy=2)
plt.imshow(resized_2x)

# %%
# Specifying exact size of the output image
desired_width = 100
desired_height = 200
dim = (desired_width, desired_height)

# Resize background image to specific size as logo image
resized_dim = cv2.resize(image, dsize=dim, interpolation=cv2.INTER_AREA)
plt.imshow(resized_dim)

# %%
# Method 2: Using 'dsize' maintaining aspect ratio of the output image
# Calculating dim arguments using fixed width maintaining aspect ratio (just ratio of new height and width to orginal rescpectively)
desired_width = 100
aspect_ratio = desired_width / image.shape[1]
desired_height = int(image.shape[0] * aspect_ratio)
dim = (desired_width, desired_height)

# Resize image
resized_image = cv2.resize(image, dsize=dim, interpolation=cv2.INTER_AREA)
plt.imshow(resized_image)

# %% [markdown]
# ### Flipping Images

# %%
# Flipping done by using flip function: cv.flip( src, flipCode ) 
# flipCode: a flag to specify how to flip the array; 0 means flipping around the x-axis and positive value (for example, 1) means flipping around y-axis. Negative value (for example, -1) means flipping around both axes.
flipped_horz = cv2.flip(image, 1)
flipped_vert = cv2.flip(image, 0)
flipped_both = cv2.flip(image, -1)

# Show the images
plt.figure(figsize=(18, 5))
plt.subplot(141);plt.imshow(flipped_horz);plt.title("Horizontal Flip");
plt.subplot(142);plt.imshow(flipped_vert);plt.title("Vertical Flip");
plt.subplot(143);plt.imshow(flipped_both);plt.title("Both Flipped");
plt.subplot(144);plt.imshow(image);plt.title("Original");

# %% [markdown]
# Check more info on opencv documentation
# https://docs.opencv.org/4.x/
